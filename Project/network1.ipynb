# %%
import json
import pandas as pd
import numpy as np
import netwulf as nw
import matplotlib.pyplot as plt
import networkx as nx
import random as random 
pd.set_option('display.max_colwidth', None)

# %%
# read json file
with open('data/characters.json') as f:
    data = json.load(f)

# %%
# convert json to dataframe where each row is a character and each column is a key
df = pd.DataFrame(data['characters'])

df.head()

# remove rows with no character link
df = df[df['characterLink'].notnull()]

# print size of dataframe
print(df.shape)

# remove characterImageThumb, characterImageFull, marriedEngaged, kingsguard, guardedBy, servedBy, guardianOf
df = df.drop(['characterImageThumb', 'characterImageFull', 'marriedEngaged', 'kingsguard', 'guardedBy', 'servedBy', 'guardianOf'], axis=1)

# print rows where housename is not nan
df[df['houseName'].notnull()]

df.houseName.value_counts()
# Out:
# (368, 25)
# Stark                     12
# Baratheon                 10
# Lannister                  9
# Martell                    7
# Frey                       6
# Greyjoy                    5
# Targaryen                  4
# Tyrell                     4
# Tully                      3
# Mormont                    3
# Bolton                     2
# [Stark, Tully]             1
# [Lannister, Baratheon]     1
# [Stark, Targaryen]         1
# [Arryn, Tully]             1
# Umber                      1
# Tarly                      1
# [Bolton, Frey]             1
# Name: houseName, dtype: int64

# %%
# create network of characters and link them to their houses
# create graph
G = nx.Graph()

# add nodes
G.add_nodes_from(df['characterName'])

# add one edge between each character if they are in the same house
for i in range(len(df)):
    for j in range(i+1, len(df)):
        if df.iloc[i]['houseName'] == df.iloc[j]['houseName']:
            G.add_edge(df.iloc[i]['characterName'], df.iloc[j]['characterName'])

# %%
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())
# Out:
# Number of nodes: 349
# Number of edges: 212

# %%
# add node attributes to the graph from the df.columns names
for i in range(len(df)):
    for col in df.columns:
        G.nodes[df.iloc[i]['characterName']][col] = df.iloc[i][col]

# %%
# remove nodes with no edge
G.remove_nodes_from(list(nx.isolates(G)))

# %%
# draw graph
nx.draw(G, with_labels=True, node_size=10, node_color='red', edge_color='black', font_size=8, width=0.1)

# %%
# nw.visualize(G)

# %% [markdown]
# #### **Episodes**

# %%
# read episodes.json file
with open('data/episodes.json') as f:
    data_episodes = json.load(f)

# %%
# convert json to dataframe where each row is an scene and each column is a key
df_episodes = pd.DataFrame(data_episodes['episodes'])

# explode scenes column
df_episodes = df_episodes.explode('scenes')

# extract all scenes from the dataframe and create a new dataframe
df_scenes = pd.DataFrame(df_episodes['scenes'].tolist())

# make a list of episode numbers
episodeNum = []
seasonNum = []
for i in range(len(df_episodes)):
    episodeNum.append(df_episodes.iloc[i]['episodeNum'])
    seasonNum.append(df_episodes.iloc[i]['seasonNum'])

df_scenes['episodeNumber'] = episodeNum
df_scenes['seasonNumber'] = seasonNum

# remove greensight, altLocation, warg and flashback columns
df_scenes = df_scenes.drop(['greensight', 'altLocation', 'warg', 'flashback'], axis=1)
df_scenes.head()

# in the characters column, extract the name of each character and add it to a list where each row is a scene
characters = []
for i in range(len(df_scenes)):
    characters.append([])
    for j in range(len(df_scenes['characters'][i])):
        characters[i].append(df_scenes['characters'][i][j]['name'])

# add the list of characters to the dataframe
df_scenes['characters'] = characters

# %%
# create one list of all characters
all_characters = []
for i in range(len(df_scenes)):
    for j in range(len(df_scenes['characters'][i])):
        all_characters.append(df_scenes['characters'][i][j])

# create a list of unique characters
unique_characters = list(set(all_characters))
print(len(unique_characters))
# Out:
# 577

# %%
# create graph of characters
G = nx.Graph()

# add nodes
G.add_nodes_from(unique_characters)

# add a weighted edge between each character if they appear in the same scene
for i in range(len(df_scenes)):
    for j in range(len(df_scenes['characters'][i])):
        for k in range(j+1, len(df_scenes['characters'][i])):
            G.add_edge(df_scenes['characters'][i][j], df_scenes['characters'][i][k], weight=1)

# %%
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 577
# 4236

# %%
# for each node, add the number of scenes they appear in as an attribute
for i in range(len(unique_characters)):
    G.nodes[unique_characters[i]]['numScenes'] = all_characters.count(unique_characters[i])

# print top 10 characters with most scenes
# sorted(G.nodes(data=True), key=lambda x: x[1]['numScenes'], reverse=True)[:10]

# %%
# find top region and top sublocation for each character
top_region = []
top_sublocation = []
for i in range(len(unique_characters)):
    top_region.append([])
    top_sublocation.append([])
    for j in range(len(df_scenes)):
        if unique_characters[i] in df_scenes['characters'][j]:
            top_region[i].append(df_scenes['location'][j])
            top_sublocation[i].append(df_scenes['subLocation'][j])

# remove nan from top_region and top_sublocation
for i in range(len(top_region)):
    top_region[i] = [x for x in top_region[i] if str(x) != 'nan']
    top_sublocation[i] = [x for x in top_sublocation[i] if str(x) != 'nan']

# if top_region or top_sublocation is empty, add nan
for i in range(len(top_region)):
    if len(top_region[i]) == 0:
        top_region[i].append('nan')
    if len(top_sublocation[i]) == 0:
        top_sublocation[i].append('nan')

   
# add top location as an attribute to each node
for i in range(len(unique_characters)):
    G.nodes[unique_characters[i]]['topRegion'] = max(set(top_region[i]), key=top_region[i].count)
    G.nodes[unique_characters[i]]['topSublocation'] = max(set(top_sublocation[i]), key=top_sublocation[i].count)

# print top 10 characters with most scenes
sorted(G.nodes(data=True), key=lambda x: x[1]['numScenes'], reverse=True)[:10]

# %%
# add houseName as an attribute to each node
for i in range(len(unique_characters)):
    for j in range(len(df)):
        if unique_characters[i] == df.iloc[j]['characterName']:
            G.nodes[unique_characters[i]]['houseName'] = df.iloc[j]['houseName']

# %%
print("Jon Snow's attributes:", G.nodes["Jon Snow"])
# Out:
# Jon Snow's attributes: {'numScenes': 632, 'topRegion': 'The North', 'topSublocation': 'Castle Black', 'houseName': ['Stark', 'Targaryen']}

# %%
import community as community_louvain

# Find communities
partition = community_louvain.best_partition(G)

len(set(partition.values()))
# Out:
# 13

# %%
# make hex colour schema for communities
colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
                for i in range(len(set(partition.values())))]

color_map = {}
for i, community in enumerate(set(partition.values())):
    color_map[community] = colors[i]

# assign community, color and degree to each node
for node in G.nodes:
    G.nodes[node]['community'] = partition[node]
    G.nodes[node]['color'] = color_map[partition[node]]
    G.nodes[node]['degree'] = G.degree[node]

# %%
# print nodes with community = 8
# for node in G.nodes:
    # if G.nodes[node]['community'] == 8:
        # print(node)

# find top location wihtin communities


# find top charachter based on numScenes within communities
top_characters = []
for i in range(len(set(partition.values()))):
    top_characters.append([])
    for node in G.nodes:
        if G.nodes[node]['community'] == i:
            top_characters[i].append(node)

# print top 10 characters in each community
top_character = []
for i in range(len(top_characters)):
    # print("Community", i)
    # print(sorted(top_characters[i], key=lambda x: G.nodes[x]['numScenes'], reverse=True)[:1])
    top_character.append(sorted(top_characters[i], key=lambda x: G.nodes[x]['numScenes'], reverse=True)[:1])

# add top character as an attribute to each node
for i in range(len(set(partition.values()))):
    for node in G.nodes:
        if G.nodes[node]['community'] == i:
            G.nodes[node]['topCommunitycharacter'] = top_character[i][0]

# %%
# calculate modularity

# %%
# calculate average degree
avg_degree = 0
for node in G.nodes:
    avg_degree += G.degree[node]
avg_degree = avg_degree / G.number_of_nodes()
print(avg_degree)
# Out:
# 14.682842287694974

# %%
# calculate the density of the graph
density = nx.density(G)
density
# Out:
# 0.02549104563835933

# %%
network, config = nw.visualize(G, plot_in_cell_below=False)
fig, ax = nw.draw_netwulf(network)
plt.savefig("BAnetworkWithDegreeColoured.pdf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-fd4b3a202da2> in <module>
#       1 network, config = nw.visualize(G, plot_in_cell_below=False)
# ----> 2 fig, ax = nw.draw_netwulf(network)
#       3 plt.savefig("BAnetworkWithDegreeColoured.pdf")
#
# /opt/homebrew/lib/python3.9/site-packages/netwulf/tools.py in draw_netwulf(network_properties, fig, ax, figsize, draw_links, draw_nodes, link_zorder, node_zorder)
#     367     ax.axis('off')
#     368     ax.margins(0)
# --> 369     ax.set_xlim(network_properties['xlim'])
#     370     ax.set_ylim(network_properties['ylim'])
#     371     bbox = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# print node attributes for nodes with highest degree
for node in sorted(G.nodes, key=lambda x: G.degree(x), reverse=True)[:20]:
    print(node, G.nodes[node])
# Out:
# Arya Stark {'characterName': 'Arya Stark', 'characterLink': '/character/ch0158604/', 'actorName': 'Maisie Williams', 'actorLink': '/name/nm3586035/', 'houseName': 'Stark', 'royal': nan, 'parents': ['Eddard Stark', 'Catelyn Stark'], 'siblings': ['Robb Stark', 'Sansa Stark', 'Bran Stark', 'Rickon Stark'], 'killedBy': nan, 'nickname': nan, 'killed': ['Red Keep Stableboy', 'Frey Soldier #1', 'Polliver', 'Rorge', 'Ghita', 'Meryn Trant', 'The Waif', 'Black Walder Rivers', 'Lothar Frey', 'Walder Frey', 'Petyr Baelish', 'The Night King', 'White Walker', 'Viserion'], 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 5, 'color': '#28518F', 'degree': 156}
# Tyrion Lannister {'characterName': 'Tyrion Lannister', 'characterLink': '/character/ch0146096/', 'actorName': 'Peter Dinklage', 'actorLink': '/name/nm0227759/', 'houseName': 'Lannister', 'royal': nan, 'parents': ['Tywin Lannister'], 'siblings': ['Cersei Lannister', 'Jaime Lannister'], 'killedBy': nan, 'nickname': nan, 'killed': ['Shae', 'Tywin Lannister'], 'parentOf': nan, 'serves': ['Daenerys Targaryen'], 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 148}
# Sansa Stark {'characterName': 'Sansa Stark', 'characterLink': '/character/ch0158137/', 'actorName': 'Sophie Turner', 'actorLink': '/name/nm3849842/', 'houseName': 'Stark', 'royal': True, 'parents': ['Eddard Stark', 'Catelyn Stark'], 'siblings': ['Robb Stark', 'Arya Stark', 'Bran Stark', 'Rickon Stark'], 'killedBy': nan, 'nickname': nan, 'killed': nan, 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 133}
# Jon Snow {'characterName': 'Jon Snow', 'characterLink': '/character/ch0155777/', 'actorName': 'Kit Harington', 'actorLink': '/name/nm3229685/', 'houseName': ['Stark', 'Targaryen'], 'royal': True, 'parents': ['Rhaegar Targaryen', 'Lyanna Stark'], 'siblings': nan, 'killedBy': ['Alliser Thorne', 'Othell Yarwyck', 'Bowen Marsh', 'Olly'], 'nickname': nan, 'killed': ['Othor', 'Qhorin Halfhand', 'Orell', 'Karl Tanner', 'Styr', 'Mance Rayder', 'Janos Slynt', 'White Walker', 'Alliser Thorne', 'Othell Yarwyck', 'Bowen Marsh', 'Olly', 'Lyanna Stark', 'Daenerys Targaryen'], 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 4, 'color': '#0AB583', 'degree': 122}
# Daenerys Targaryen {'characterName': 'Daenerys Targaryen', 'characterLink': '/character/ch0158597/', 'actorName': 'Emilia Clarke', 'actorLink': '/name/nm3592338/', 'houseName': 'Targaryen', 'royal': True, 'parents': ['Aerys II Targaryen', 'Rhaella Targaryen'], 'siblings': ['Rhaegar Targaryen', 'Viserys Targaryen'], 'killedBy': ['Jon Snow'], 'nickname': nan, 'killed': ['Khal Drogo', 'Mirri Maz Duur', 'Doreah', 'Xaro Xhoan Daxos', 'Khal Rhalko', 'Khal Brozho', 'Khal Qorro', 'Khal Forzho', 'Khal Moro', 'Dothraki Bloodrider #1', 'Dothraki Bloodrider #2', 'Randyll Tarly', 'Dickon Tarly', 'Eleanor', "Eleanor's Daughter", 'Lord Varys'], 'parentOf': ['Rhaego'], 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 11, 'color': '#D10965', 'degree': 113}
# Jaime Lannister {'characterName': 'Jaime Lannister', 'characterLink': '/character/ch0158527/', 'actorName': 'Nikolaj Coster-Waldau', 'actorLink': '/name/nm0182666/', 'houseName': 'Lannister', 'royal': nan, 'parents': ['Tywin Lannister'], 'siblings': ['Cersei Lannister', 'Tyrion Lannister'], 'killedBy': ['Roof collapse'], 'nickname': 'The Kingslayer', 'killed': ['Aerys II Targaryen', 'Jory Cassel', 'Alton Lannister', 'Torrhen Karstark', 'Olenna Tyrell', 'Euron Greyjoy'], 'parentOf': ['Joffrey Baratheon', 'Myrcella Baratheon', 'Tommen Baratheon'], 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 112}
# Theon Greyjoy {'characterName': 'Theon Greyjoy', 'characterLink': '/character/ch0158526/', 'actorName': 'Alfie Allen', 'actorLink': '/name/nm0654295/', 'houseName': 'Greyjoy', 'royal': nan, 'parents': ['Balon Greyjoy'], 'siblings': ['Yara Greyjoy'], 'killedBy': ['The Night King'], 'nickname': nan, 'killed': ['Stiv', 'Rodrik Cassel', 'Myranda', 'Bolton Soldier', 'Harrag'], 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 1, 'color': '#BF1D03', 'degree': 108}
# Bran Stark {'characterName': 'Bran Stark', 'characterLink': '/character/ch0234897/', 'actorName': 'Isaac Hempstead Wright', 'actorLink': '/name/nm3652842/', 'houseName': 'Stark', 'royal': True, 'parents': ['Eddard Stark', 'Catelyn Stark'], 'siblings': ['Robb Stark', 'Sansa Stark', 'Arya Stark', 'Rickon Stark'], 'killedBy': nan, 'nickname': nan, 'killed': nan, 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 1, 'color': '#BF1D03', 'degree': 105}
# Sandor Clegane {'characterName': 'Sandor Clegane', 'characterLink': '/character/ch0162882/', 'actorName': 'Rory McCann', 'actorLink': '/name/nm0564920/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': ['Gregor Clegane'], 'killedBy': ['Sandor Clegane'], 'nickname': 'The Hound', 'killed': ['Mycah', 'Kings Landing Rioter #1', 'Kings Landing Rioter #2', 'Kings Landing Rioter #3', 'Beric Dondarrion', 'Frey Soldier #2', 'Lowell', 'Dying Man', 'Biter', 'Steve', 'Riddell', 'Gatins', 'Morgan', 'Lem Lemoncloak', 'Gregor Clegane', 'Sandor Clegane'], 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 5, 'color': '#28518F', 'degree': 103}
# Cersei Lannister {'characterName': 'Cersei Lannister', 'characterLink': '/character/ch0159526/', 'actorName': 'Lena Headey', 'actorLink': '/name/nm0372176/', 'houseName': ['Lannister', 'Baratheon'], 'royal': True, 'parents': ['Tywin Lannister'], 'siblings': ['Jaime Lannister', 'Tyrion Lannister'], 'killedBy': ['Roof collapse'], 'nickname': nan, 'killed': ['Lancel Lannister', 'High Sparrow', 'Loras Tyrell', 'Mace Tyrell', 'Margaery Tyrell', 'Kevan Lannister', 'Tyene Sand'], 'parentOf': ['Joffrey Baratheon', 'Myrcella Baratheon', 'Tommen Baratheon'], 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 99}
# Lord Varys {'characterName': 'Lord Varys', 'characterLink': '/character/ch0249636/', 'actorName': 'Conleth Hill', 'actorLink': '/name/nm0384152/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': nan, 'killedBy': ['Daenerys Targaryen'], 'nickname': nan, 'killed': nan, 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 93}
# Davos Seaworth {'characterName': 'Davos Seaworth', 'characterLink': '/character/ch0255396/', 'actorName': 'Liam Cunningham', 'actorLink': '/name/nm0192377/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': nan, 'killedBy': nan, 'nickname': nan, 'killed': nan, 'parentOf': ['Matthos Seaworth'], 'serves': ['Stannis Baratheon', 'Jon Snow'], 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 4, 'color': '#0AB583', 'degree': 92}
# Samwell Tarly {'characterName': 'Samwell Tarly', 'characterLink': '/character/ch0244961/', 'actorName': 'John Bradley', 'actorLink': '/name/nm4263213/', 'houseName': nan, 'royal': nan, 'parents': ['Randyll Tarly', 'Melessa Tarly'], 'siblings': ['Dickon Tarly', 'Talla Tarly'], 'killedBy': nan, 'nickname': nan, 'killed': ['White Walker', 'Thenn Warg'], 'parentOf': ['Baby Sam'], 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 4, 'color': '#0AB583', 'degree': 89}
# Jorah Mormont {'characterName': 'Jorah Mormont', 'characterLink': '/character/ch0158221/', 'actorName': 'Iain Glen', 'actorLink': '/name/nm0322513/', 'houseName': 'Mormont', 'royal': nan, 'parents': ['Jeor Mormont'], 'siblings': nan, 'killedBy': ['Wights'], 'nickname': nan, 'killed': ['Qotho', 'Norvoshi Pit Fighter', 'Meereenese Champion'], 'parentOf': nan, 'serves': ['Daenerys Targaryen'], 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 11, 'color': '#D10965', 'degree': 87}
# Bronn {'characterName': 'Bronn', 'characterLink': '/character/ch0241345/', 'actorName': 'Jerome Flynn', 'actorLink': '/name/nm0283492/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': nan, 'killedBy': nan, 'nickname': nan, 'killed': ['Vardis Egen', 'Matthos Seaworth', 'Lead Dornish Guard'], 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 80}
# Brienne of Tarth {'characterName': 'Brienne of Tarth', 'characterLink': '/character/ch0254503/', 'actorName': 'Gwendoline Christie', 'actorLink': '/name/nm3729225/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': nan, 'killedBy': nan, 'nickname': nan, 'killed': ['Soldier Tom', 'Stannis Baratheon', 'Bolton Officer'], 'parentOf': nan, 'serves': ['Renly Baratheon', 'Catelyn Stark', 'Sansa Stark', 'Bran Stark'], 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 79}
# Petyr Baelish {'characterName': 'Petyr Baelish', 'characterLink': '/character/ch0245982/', 'actorName': 'Aidan Gillen', 'actorLink': '/name/nm0318821/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': nan, 'killedBy': ['Arya Stark'], 'nickname': 'Littlefinger', 'killed': ['Joffrey Baratheon', 'Dontos Hollard', 'Lysa Arryn'], 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 73}
# Tormund Giantsbane {'characterName': 'Tormund Giantsbane', 'characterLink': '/character/ch0316925/', 'actorName': 'Kristofer Hivju', 'actorLink': '/name/nm1970465/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': nan, 'killedBy': nan, 'nickname': nan, 'killed': ['Rattleshirt', 'Smalljon Umber'], 'parentOf': nan, 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 4, 'color': '#0AB583', 'degree': 72}
# Podrick Payne {'characterName': 'Podrick Payne', 'characterLink': '/character/ch0306046/', 'actorName': 'Daniel Portman', 'actorLink': '/name/nm4535552/', 'houseName': nan, 'royal': nan, 'parents': nan, 'siblings': nan, 'killedBy': nan, 'nickname': nan, 'killed': ['Mandon Moore', 'Bolton Soldier'], 'parentOf': nan, 'serves': ['Tyrion Lannister', 'Brienne of Tarth', 'Bran Stark'], 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 0, 'color': '#1306C4', 'degree': 71}
# Catelyn Stark {'characterName': 'Catelyn Stark', 'characterLink': '/character/ch0145135/', 'actorName': 'Michelle Fairley', 'actorLink': '/name/nm0265610/', 'houseName': ['Stark', 'Tully'], 'royal': nan, 'parents': ['Hoster Tully'], 'siblings': ['Lysa Arryn', 'Edmure Tully'], 'killedBy': ['Black Walder Rivers'], 'nickname': nan, 'killed': ['Joyeuse Erenford'], 'parentOf': ['Robb Stark', 'Sansa Stark', 'Arya Stark', 'Bran Stark', 'Rickon Stark'], 'serves': nan, 'actors': nan, 'allies': nan, 'abductedBy': nan, 'abducted': nan, 'sibling': nan, 'community': 1, 'color': '#BF1D03', 'degree': 70}

# %%
# Out:
# Community 0
# Addam Marbrand
# Areo Hotah
# Armeca
# Brienne of Tarth
# Bronn
# Captain of the Archers
# Cersei Lannister
# Colen of Greenpools
# Daisy
# Dickon Tarly
# Dontos Hollard
# Doran Martell
# Ellaria Sand
# Euron Greyjoy
# Grand Maester Pycelle
# Gregor Clegane
# Hallyne
# Handmaid
# High Septon
# High Sparrow
# Ilyn Payne
# Jaime Lannister
# Joffrey Baratheon
# Jon Arryn
# Kayla
# Kevan Lannister
# King Joffrey Baratheon Dwarf
# King Renly Baratheon Dwarf
# King Robb Stark Dwarf
# King Stannis Baratheon Dwarf
# Kinvara
# Lancel Lannister
# Lannister Captain
# Lannister Messenger
# Lead Dornish Guard
# Leo Lefford
# Lollys Stokeworth
# Loras Tyrell
# Lord Varys
# Mace Tyrell
# Maester Wolkan
# Mandon Moore
# Marei
# Margaery Tyrell
# Margaery's Handmaiden
# Marillion
# Merchant Captain
# Meryn Trant
# Mirelle
# Myrcella Baratheon
# Nymeria Sand
# Obara Sand
# Oberyn Martell
# Olenna Tyrell
# Olyvar
# Petyr Baelish
# Podrick Payne
# Qyburn
# Randyll Tarly
# Red Priestess
# Renly Baratheon
# Ros
# Sansa Stark
# Septa Moelle
# Septa Scolera
# Septa Unella
# Shae
# Shagga
# Steelshanks Walton
# The Bear
# Timett
# Tommen Baratheon
# Trystane Martell
# Tycho Nestoris
# Tyene Sand
# Tyrion Lannister
# Tywin Lannister
# Zanrush
# Chella
# Gerard
# Protestor
# Singing Lannister Soldier
# Soldier Tom
# Stark Soldier
# Orphan Kid
# Riverlands Traveller
# King's Landing Tailor
# Tyrell Servant
# Genna
# Sorcerer
# Tyrell Lady
# Desmond Crakehall
# Eldrick Sarsfield
# Fruit Vendor
# Lord Blackmont
# Morgan's Friend
# King Balon Greyjoy Dwarf
# King's Landing Whore
# Inn Waitress
# Eyrie Guard
# Dwarf Hunter #1
# Dwarf Hunter #2
# Old Woman
# The Stranger
# The Warrior
# The Smith
# The Mother
# The Maiden
# The Crone
# Beggar Woman
# Brothel Guard
# Sellsword #1
# Sellsword #2
# The Mother of Dragons
# Clea
# Winter Town Man
# Tyrell Guard
# King's Landing Drunkard
# King's Landing Flasher #1
# King's Landing Flasher #2
# Bolton Officer
# Bolton Soldier
# Maester Caleotte
# Meereenese Homeless Mother
